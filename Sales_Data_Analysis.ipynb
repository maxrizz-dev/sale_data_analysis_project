# %% [markdown]
# #DATA ANALYSIS ON SALES DATA
#  Tools : Numpy| pandas | Matplotlib

# %% [markdown]
# IMPORT PYTHON LIBRARIES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# #SECTION A - LOADING THE DATASET

# %%
#Import csv file
df = pd.read_csv("Diwali Sales Data - Diwali Sales Data.csv", encoding = "unicode_escape")

# %% [markdown]
# we use encoding='unicode_escape' primarily to fix decoding errors that occur when a file contains characters or escape sequences that the default utf-8 decoder cannot process.

# %%
df
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %% [markdown]
# #SECTION B - EXPLORING THE DATASET

# %%
df.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#              State      Zone       Occupation Product_Category  Orders  \
# 0      Maharashtra   Western       Healthcare             Auto       1
# 1  AndhraÂ Pradesh  Southern             Govt             Auto       3
# 2    Uttar Pradesh   Central       Automobile             Auto       3
# 3        Karnataka  Southern     Construction             Auto       2
# 4          Gujarat   Western  Food Processing             Auto       2
#
#     Amount  Status  unnamed1
# 0  23952.0     NaN       NaN
# 1  23934.0     NaN       NaN
# ...

# %%
df.tail()
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
#                 State      Zone   Occupation Product_Category  Orders  Amount  \
# 11246     Maharashtra   Western     Chemical           Office       4   370.0
# 11247         Haryana  Northern   Healthcare       Veterinary       3   367.0
# 11248  Madhya Pradesh   Central      Textile           Office       4   213.0
# 11249       Karnataka  Southern  Agriculture           Office       3   206.0
# 11250     Maharashtra   Western   Healthcare           Office       3   188.0
#
#        Status  unnamed1
# ...

# %% [markdown]
# Structure of data

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  str
#  2   Product_ID        11251 non-null  str
#  3   Gender            11251 non-null  str
#  4   Age Group         11251 non-null  str
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  str
#  8   Zone              11251 non-null  str
#  9   Occupation        11251 non-null  str
#  10  Product_Category  11251 non-null  str
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), str(8)
# memory usage: 1.3 MB

# %% [markdown]
# Statistical Summary

# %%
df.describe()
# Out:
#             User_ID           Age  Marital_Status        Orders        Amount  \
# count  1.125100e+04  11251.000000    11251.000000  11251.000000  11239.000000
# mean   1.003004e+06     35.421207        0.420318      2.489290   9453.610858
# std    1.716125e+03     12.754122        0.493632      1.115047   5222.355869
# min    1.000001e+06     12.000000        0.000000      1.000000    188.000000
# 25%    1.001492e+06     27.000000        0.000000      1.500000   5443.000000
# 50%    1.003065e+06     33.000000        0.000000      2.000000   8109.000000
# 75%    1.004430e+06     43.000000        1.000000      3.000000  12675.000000
# max    1.006040e+06     92.000000        1.000000      4.000000  23952.000000
#
#        Status  unnamed1
# count     0.0       0.0
# mean      NaN       NaN
# std       NaN       NaN
# min       NaN       NaN
# 25%       NaN       NaN
# 50%       NaN       NaN
# 75%       NaN       NaN
# max       NaN       NaN

# %% [markdown]
# summary of categorical column

# %%
df.describe(include="object")
# Out:
# C:\Users\itzzr\AppData\Local\Temp\ipykernel_20352\702825166.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   df.describe(include="object")
#        Cust_name Product_ID Gender Age Group          State     Zone  \
# count      11251      11251  11251     11251          11251    11251
# unique      1250       2351      2         7             16        5
# top     Vishakha  P00265242      F     26-35  Uttar Pradesh  Central
# freq          42         53   7842      4543           1946     4296
#
#        Occupation    Product_Category
# ...

# %% [markdown]
# #SECTION C - CLEANING THE DATASET

# %%
df.isnull().sum()
# Out:
# User_ID                 0
# Cust_name               0
# Product_ID              0
# Gender                  0
# Age Group               0
# Age                     0
# Marital_Status          0
# State                   0
# Zone                    0
# Occupation              0
# Product_Category        0
# Orders                  0
# Amount                 12
# Status              11251
# unnamed1            11251
# dtype: int64

# %% [markdown]
#  Drop fully-empty columns

# %%
df.drop(['Status','unnamed1'], axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 df.drop(['Status','unnamed1'], axis=1, inplace=True)
#
# File c:\Users\itzzr\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\frame.py:6288, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    6284                 weight  250.0   150.0
#    6285         falcon  speed   320.0   250.0
#    6286                 weight  1.0     0.8
#    6287         """
# -> 6288         return super().drop(
#    6289             labels=labels,
#    6290             axis=axis,
#    6291             index=index,
#
# File c:\Users\itzzr\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\generic.py:4644, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4640         obj = self
#    4641
# ...

# %% [markdown]
#  Drop rows where Amount is missing

# %%
df.dropna(subset=['Amount'], inplace=True)

# %%
df.isnull().sum()
# Out:
# User_ID             0
# Cust_name           0
# Product_ID          0
# Gender              0
# Age Group           0
# Age                 0
# Marital_Status      0
# State               0
# Zone                0
# Occupation          0
# Product_Category    0
# Orders              0
# Amount              0
# dtype: int64

# %% [markdown]
# checking for duplicates value

# %%
df_dup = df.duplicated().sum()

# %%
df_dup
# Out:
# np.int64(8)

# %%
df_cleaned = df.drop_duplicates()

# %%
new_dup_count = df_cleaned.duplicated().sum()
print(new_dup_count)
# Out:
# 0

# %% [markdown]
# incorrect data type

# %%
df['Amount'] = df['Amount'].astype(int)

# %% [markdown]
# #SECTION D - EXPLORATORY DATA ANALYSIS

# %%
plt.figure(figsize=(8,5))
plt.scatter(df['Age'], df['Amount'], alpha=0.5)
plt.title("Age vs Investment")
plt.xlabel("Age")
plt.ylabel("Investment Amount")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(7,7))
gender_investment.plot(
    kind='pie',
    autopct='%1.1f%%'
)
plt.title("Gender Wise Investment Share")
plt.ylabel("")
plt.show()

# %%
age_investment = df.groupby('Age')['Amount'].sum()

plt.figure(figsize=(10,5))
plt.plot(age_investment.index, age_investment.values, marker='o')
plt.title("Age Wise Investment Trend")
plt.xlabel("Age")
plt.ylabel("Total Investment")
plt.grid(True)
plt.show()

# %%
top_occupation = occupation_investment.sort_values(ascending=False).head(10)

plt.figure(figsize=(8,8))
top_occupation.plot(
    kind='pie',
    autopct='%1.1f%%'
)
plt.title("Top 10 Occupation Investment Share")
plt.ylabel("")
plt.show()

# %%
age_count = df['Age'].value_counts().sort_index()

plt.figure(figsize=(12,6))
age_count.plot(kind='bar')
plt.title("Customer Count by Age")
plt.xlabel("Age")
plt.ylabel("Number of Customers")
plt.grid(axis='y')
plt.show()
